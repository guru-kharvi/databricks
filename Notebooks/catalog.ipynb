-- %%
%sql
describe catalog extended dev

-- %%
CREATE CATALOG IF NOT EXISTS dev_sql
  MANAGED LOCATION 'abfss://destination@databricksguru.dfs.core.windows.net/dev_sql';

-- %%
drop catalog dev_sql cascade

-- %%
create table dev_ext.ext_dev_bronz.emp(

empno int,
ename string,
dept_code string
);

-- %%
drop catalog dev_ext cascade
